# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Chapter-4:-Functions-and-Automation" data-toc-modified-id="Chapter-4:-Functions-and-Automation-1">Chapter 4: Functions and Automation</a></span><ul class="toc-item"><li><span><a href="#1.-Basic-functions-in-Bash" data-toc-modified-id="1.-Basic-functions-in-Bash-1.1">1. Basic functions in Bash</a></span><ul class="toc-item"><li><span><a href="#Bash-function-anatomy" data-toc-modified-id="Bash-function-anatomy-1.1.1">Bash function anatomy</a></span></li><li><span><a href="#Alternate-Bash-function-structure" data-toc-modified-id="Alternate-Bash-function-structure-1.1.2">Alternate Bash function structure</a></span></li><li><span><a href="#How-to-call-a-Bash-function" data-toc-modified-id="How-to-call-a-Bash-function-1.1.3">How to call a Bash function</a></span></li><li><span><a href="#Fahrenheit-to-Celsius-Bash-function---example" data-toc-modified-id="Fahrenheit-to-Celsius-Bash-function---example-1.1.4">Fahrenheit to Celsius Bash function - example</a></span></li><li><span><a href="#Uploading-model-results-to-the-cloud---exercise" data-toc-modified-id="Uploading-model-results-to-the-cloud---exercise-1.1.5">Uploading model results to the cloud - exercise</a></span></li><li><span><a href="#Get-the-current-day---exercise" data-toc-modified-id="Get-the-current-day---exercise-1.1.6">Get the current day - exercise</a></span></li></ul></li><li><span><a href="#2.-Arguments,-return-values,-and-scope" data-toc-modified-id="2.-Arguments,-return-values,-and-scope-1.2">2. Arguments, return values, and scope</a></span><ul class="toc-item"><li><span><a href="#Passing-arguments-into-Bash-functions" data-toc-modified-id="Passing-arguments-into-Bash-functions-1.2.1">Passing arguments into Bash functions</a></span></li><li><span><a href="#Scope-in-programming" data-toc-modified-id="Scope-in-programming-1.2.2">Scope in programming</a></span></li><li><span><a href="#Scope-in-Bash-functions" data-toc-modified-id="Scope-in-Bash-functions-1.2.3">Scope in Bash functions</a></span></li><li><span><a href="#Restricting-scope-in-Bash-functions" data-toc-modified-id="Restricting-scope-in-Bash-functions-1.2.4">Restricting scope in Bash functions</a></span></li><li><span><a href="#Return-values" data-toc-modified-id="Return-values-1.2.5">Return values</a></span></li><li><span><a href="#A-return-error" data-toc-modified-id="A-return-error-1.2.6">A return error</a></span></li><li><span><a href="#Returning-correctly" data-toc-modified-id="Returning-correctly-1.2.7">Returning correctly</a></span></li><li><span><a href="#A-percentage-calculator---exercise" data-toc-modified-id="A-percentage-calculator---exercise-1.2.8">A percentage calculator - exercise</a></span></li><li><span><a href="#Sports-analytics-function---exercise" data-toc-modified-id="Sports-analytics-function---exercise-1.2.9">Sports analytics function - exercise</a></span></li><li><span><a href="#Summing-an-array---exercise" data-toc-modified-id="Summing-an-array---exercise-1.2.10">Summing an array - exercise</a></span></li></ul></li><li><span><a href="#3.-Scheduling-your-scripts-with-Cron" data-toc-modified-id="3.-Scheduling-your-scripts-with-Cron-1.3">3. Scheduling your scripts with Cron</a></span><ul class="toc-item"><li><span><a href="#Crontab-and-cronjob-structure" data-toc-modified-id="Crontab-and-cronjob-structure-1.3.1">Crontab and cronjob structure</a></span></li><li><span><a href="#Cronjob-example" data-toc-modified-id="Cronjob-example-1.3.2">Cronjob example</a></span></li><li><span><a href="#Advanced-cronjob-structure" data-toc-modified-id="Advanced-cronjob-structure-1.3.3">Advanced cronjob structure</a></span></li><li><span><a href="#Your-first-cron-job" data-toc-modified-id="Your-first-cron-job-1.3.4">Your first cron job</a></span></li><li><span><a href="#Analyzing-a-crontab-schedule---Quiz" data-toc-modified-id="Analyzing-a-crontab-schedule---Quiz-1.3.5">Analyzing a crontab schedule - Quiz</a></span></li><li><span><a href="#Creating-cronjobs---exercise" data-toc-modified-id="Creating-cronjobs---exercise-1.3.6">Creating cronjobs - exercise</a></span></li><li><span><a href="#Scheduling-cronjobs-with-crontab---exercise" data-toc-modified-id="Scheduling-cronjobs-with-crontab---exercise-1.3.7">Scheduling cronjobs with crontab - exercise</a></span></li><li><span><a href="#Thanks-and-wrap-up" data-toc-modified-id="Thanks-and-wrap-up-1.3.8">Thanks and wrap up</a></span></li></ul></li></ul></li></ul></div>

# %% [markdown]
# # Chapter 4: Functions and Automation

# %% [markdown]
# Give your Bash scripts a powerful new addition by building useful functions to process data and variables.
#
# In this last chapter, you will learn
#
# * the structure of functions in Bash,
# * how to use functions to help automate frequent tasks, and
# * program your scripts to run on schedule without needing to even lift a finger.

# %% [markdown]
# ## 1. Basic functions in Bash

# %% [markdown]
# ### Bash function anatomy
#
# ![Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell1.png](attachment:Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell1.png)

# %% [markdown]
# ### Alternate Bash function structure
#
# ![Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell2.png](attachment:Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell2.png)

# %% [markdown]
# ### How to call a Bash function
#
# ![Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell3.png](attachment:Screenshot_2021-06-04%20Basic%20functions%20in%20Bash%20Shell3.png)

# %% [markdown]
# ### Fahrenheit to Celsius Bash function - example

# %%
# Creating the function

# static variable temp
temp_f=30

# Creating the function with the function-word method 
function convert_temp () {
    temp_c=$(echo "scale=2; ($temp_f-32)*5/9" | bc)
    
    echo $temp_c
}

# %%
# Calling the function
convert_temp
# Out:
# -1.11

# %% [markdown]
# 30ºF is -1.11ªC

# %% [markdown]
# ### Uploading model results to the cloud - exercise
#
# You are working as a data scientist on building part of your machine learning cloud infrastructure. Your team has many machine learning experiments running all the time. When an experiment is finished, it will output the results file and a configuration file into a folder called `output_dir/`.
#
# These results need to be uploaded to your cloud storage environment for analysis. Your task is to write a Bash script that contains a function which will loop through all the files in `output_dir/` and upload the result files to your cloud storage.
#
# For technical reasons, no files will be uploaded; we will simply echo out the file name. Though you could easily replace this section with code to upload to Amazon S3, Google Cloud or Microsoft Azure!
#
# **Instructions**
#
# * Set up a function using the 'function-word' method called `upload_to_cloud`.
# * Use a FOR statement to loop through (using glob expansion) files whose names contain `results` in `output_dir/` and `echo` that the filename is being uploaded to the cloud.
# * Call the function just below the function definition using its name.

# %%
# Datacamp answer

# Create function
function upload_to_cloud () {
  # Loop through files with glob expansion
  for file in output_dir/*results*
  do
    # Echo that they are being uploaded
    echo "Uploading $file to cloud"
  done
}

# Call the function
upload_to_cloud

# %% [markdown]
# Now we have a useful modularized piece of code that we can build on for our data pipeline. Rather than having to copy and paste that loop multiple places in your code, you can call the function with just one line. Let's build on this by practicing building more functions in Bash.

# %% [markdown]
# ### Get the current day - exercise
#
# Whilst working on a variety of Bash scripts in your data analytics infrastructure, you find that you often need to get the current day of the week. You can see this is unnecessary duplication of code and can be refactored (reduce the size by writing more efficient code) using your new skills in Bash functions.
#
# Write a simple Bash function that, when called, will simply print out the current day of the week. This will involve parsing the output of the `date` program from a shell-within-a-shell.
#
# A reminder that the output of `date` will look something like this (depending on the timezone you are calling it from!)
#
# `Fri 27 Dec 2019 14:24:33 AEDT`
#
# You want to extract the `Fri` part only.
#
# **Instructions**
#
# * Set up a function called `what_day_is_it` **without** using the word function (as you did using the function-word method).
# * Parse the output of `date` into a variable called `current_day`. The extraction component has been done for you.
# * Echo the result.
# * Call the function just below the function definition.

# %%
date
# Out:
# Fri Jun  4 17:36:38 -05 2021

# %%
# with sed
date | sed 's/ .*//'
# Out:
# Fri

# %%
# with cut -d " " -f x
date | cut -d " " -f 1
# Out:
# Fri

# %%
date | cut -d " " -f1
# Out:
# Fri

# %%
# creating the function without using the word function
what_day_is_it () {
    current_day=$(date | sed 's/ .*//')
    echo $current_day
}

# calling the function
what_day_is_it
# Out:
# Fri

# %%
# creating the function without using the word function
what_day_is_it2 () {
    current_day=$(date | cut -d " " -f1)
    echo $current_day
}

# calling the function
what_day_is_it2
# Out:
# Fri

# %% [markdown]
# Let's build on this work with functions to create some more advanced functions with arguments!

# %% [markdown]
# ## 2. Arguments, return values, and scope

# %% [markdown]
# Let's learn how to get data into and out of our functions and how scope affects this process.

# %% [markdown]
# ### Passing arguments into Bash functions

# %% [markdown]
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell1.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell1.png)

# %% [markdown]
# In this example, we will pass in some file names, loop through and print them out.
#
# Inside our function code, we
#
# * firstly echo the first ARGV element using `$1` notation.
# * Then we use a FOR loop over all the elements using `$@`.
# * The last line calls this function with some file names.
#
# See how the output is the first file name and then each file name (including the first) in turn.

# %% [markdown]
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell2.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell2.png)

# %% [markdown]
# We can assign the first argument `$1` to a variable (like I did here) or simple refer to the first argument as `$1`.

# %%
# same function

# creating the function with the function-word method
function print_filename () {
    echo "The first file was $1"
    
    # looping through each file passed to the function
    for file in $@
    do
        echo "The name of this file is $file"
    done
}

# %%
# calling the function with 4 files as arguments
print_filename ../data/new_hires.csv ../data/words.txt ../data/soccer_scores_edited.csv ../data/soccer_scores.csv
# Out:
# The first file was ../data/new_hires.csv
# The name of this file is ../data/new_hires.csv
# The name of this file is ../data/words.txt
# The name of this file is ../data/soccer_scores_edited.csv
# The name of this file is ../data/soccer_scores.csv

# %%
# test
function print_filename2 () {
    first_file=$1
    
    echo "The first file was $first_file"
}

# %%
print_filename2 ../data/new_hires.csv ../data/words.txt ../data/soccer_scores_edited.csv ../data/soccer_scores.csv
# Out:
# The first file was ../data/new_hires.csv

# %% [markdown]
# We can assign the first argument `$1` to a variable (like I did here) or simple refer to the first argument as `$1` like we did before.

# %% [markdown]
# ### Scope in programming

# %% [markdown]
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell3.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell3.png)

# %% [markdown]
# Scope is an important programming concept. It refers to how accessible a variable is within the program.
#
# * Global scope is where a variable is accessible anywhere including inside sections such as FOR loops, IF statements, and functions.
# * Local scope is a variable only accessible in a certain part of the program.
#
# Why is this important? Because if you try and access a variable outside where it has local scope - your program may fail with an error!

# %% [markdown]
# ### Scope in Bash functions

# %% [markdown]
# Bash makes it easy as all variables are global by default.
#
# In this example function, we create a variable from the first argument inside.
#
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell4.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell4.png)
#
# After calling the function, we echo the variable created inside. It works!
#
# Beware. Many languages limit global scope by default as this carries risks you may accidentally do something unintended.

# %%
# creating the function
function print_filename3 () {
    first_filename=$1
}

# %%
# we give arguments (files) to the function. the variable first_filename gets assigned to the first argument $1
print_filename3 ../data/words.txt ../data/soccer_scores_edited.csv ../data/soccer_scores.csv

# %%
echo $first_filename
# Out:
# ../data/words.txt

# %% [markdown]
# ### Restricting scope in Bash functions

# %% [markdown]
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell5.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell5.png)

# %%
function print_filename4 () {
    # keyword to restrict scope of variable
    local first_filename3=$1
}

# %%
print_filename4 ../data/soccer_scores_edited.csv ../data/soccer_scores.csv

# %%
# calling the variable created inside the function
echo $first_filename3

# %%
print_filename4

# %%
echo $first_filename3

# %% [markdown]
# ### Return values
#
# Knowing how to get arguments in functions, how do we get data out?
#
# 'return' in Bash is not for data. It contains a value based on whether the function was successful (0) or not (other values 1-255).
#
# This value is in the global variable `$?`.
#
# Therefore, we could:
#
# * Assign what we want to a global variable and access anywhere outside.
# * Or, we can `echo` what we want returned as the last line in the function and capture using shell-within-a-shell.
#
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell6.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell6.png)

# %% [markdown]
# ### A return error
#
# This is an example of return being used with an error.
#
# We create a function that has an error inside. We call the function then print out the return value using `$?`.
#
# As expected, trying to call a non-existent program `'echlo'` did not work and there was an error.
#
# The return value 127 means the script tried to find a program that doesn't exist.
#
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell7.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell7.png)

# %% [markdown]
# ### Returning correctly
#
# Let's return what we want using the second method. `'echo'` and `shell-within-a-shell`.
#
# Using the temperature conversion function from before, we echo back the calculation result inside the function. Below, we assign the variable 'converted' to what is returned from the function when using the argument '30'. Then echo using that variable. We get the correct return value. Notice how we didn't use an intermediary variable this time?
#
# ![Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell8.png](attachment:Screenshot_2021-06-04%20Arguments,%20return%20values,%20and%20scope%20Shell8.png)

# %%
# creating function
function convert_temp () {
    echo $(echo "scale=2; ($1-32)*5/9" | bc)
}

# %%
converted=$(convert_temp 30)

echo "30F in Celsius is ${converted}C"
# Out:
# 30F in Celsius is -1.11C

# %% [markdown]
# I can just use the first argument as `$1` or I could assign it to a variable:

# %%
# creating function v2
# assigning argumen 1 ($1) to a variable
function convert_temp2 () {
    local temp_user_c=$1
    # the conversion to celsius
    echo $(echo "scale=2; ($temp_user_c-32)*5/9" | bc)
}

# %%
converted2=$(convert_temp2 50)

echo "50F in Celsius is ${converted2}C"
# Out:
# 50F in Celsius is 10.00C

# %% [markdown]
# ### A percentage calculator - exercise
#
# In your work as a data scientist, you often find yourself needing to calculate percentages within Bash scripts. This would be a great opportunity to create a nice modular function to be called from different places in your code.
#
# Your task is to create a Bash function that will calculate a percentage of two numbers that are given as arguments and return the value.
#
# A test example you can think of to use in this script is a model that you just ran where there were 456 correct predictions out of 632 on the test set.
#
# Remember that the shell can't natively handle decimal places, so it will be safer to employ the use of `bc`.
#
# **Instructions**
#
# * Create a function called `return_percentage` using the function-word method.
# * Create a variable inside the function called `percent` that divides the first argument fed into the function by the second argument.
# * Return the calculated value by echoing it back.
# * Call the function with the mentioned test values of 456 (the first argument) and 632 (the second argument) and echo the result.

# %%
function return_percentage_v1 () {
    # calculating the percentage
    percent=$(echo "scale=2; 100*$1/$2" | bc)  # ($1/$2)*100 and $1/$2*100 don't give the result with decimals
    # returning the calculated value by echoing it back
    echo $percent
}

# %%
return_percentage_v1 456 632
# Out:
# 72.15

# %%
return_test_v1=$(return_percentage_v1 456 632)

echo "456 out of 632 in percentage is $return_test_v1%"
echo "456 out of 632 in percentage is ${return_test_v1}%"
# Out:
# 456 out of 632 in percentage is 72.15%
# 456 out of 632 in percentage is 72.15%

# %%
# Datacamp answer

# Create a function 
function return_percentage () {

  # Calculate the percentage using bc
  percent=$(echo "scale=2; 100 * $1 / $2" | bc)

  # Return the calculated percentage
  echo $percent
}

# Call the function with 456 and 632 and echo the result
return_test=$(return_percentage 456 632)
echo "456 out of 632 as a percent is $return_test%"

# %%
bash script

# %% [markdown]
# 456 out of 632 as a percent is 72.15%

# %% [markdown]
# We were able to accept and use arguments AND return values for use.

# %% [markdown]
# ### Sports analytics function - exercise
#
# You have been contracted back to the soccer league to help them with some sports analytics. You notice that a number of the scripts undertake aggregations, just like you did in a previous exercise. Since there is a lot of duplication of code, this is an excellent opportunity to create a single useful function that can be called at many places in the script.
#
# Your task is to create a Bash function that will take in a city name and find out how many wins they have had since recording began.
#
# Inside the main function, this script will call out to a shell-within-a-shell which is captured in a (by default, global) variable. You can then access this variable outside the function. This was the first technique discussed in the video for getting data out of a function.
#
# Most of the shell pipeline used has been done for you, though of course feel free to explore and understand what is happening here. Nothing there should be new to you!
#
# **Instructions**
#
# * Create a function called `get_number_wins` using the function-word method.
# * Create a variable inside the function called `win_stats` that takes the argument fed into the function to filter the last step of the shell-pipeline presented.
# * Call the function using the city `Etar`.
# * Below the function call, try to access the `win_stats` variable created inside the function in the `echo` command presented.

# %%
head ../data/soccer_scores.csv
# Out:
# ﻿Year,Winner,Winner Goals
# 1932,Arda,4
# 1933,Botev,1
# 1934,Cherno,5
# 1935,Dunav,2
# 1936,Cherno,4
# 1937,Dunav,4
# 1938,Beroe,5
# 1939,Botev,2
# 1940,Beroe,3

# %%
grep "Etar" ../data/soccer_scores.csv | wc -l
# Out:
# 15

# %%
grep -c "Etar" ../data/soccer_scores.csv
# Out:
# 15

# %%
function get_number_wins () {
    # function takes in a city name
    city=$1
    # finding out how many wins they have had
    win_stats=$(grep -c "$city" ../data/soccer_scores.csv)
    # This is a global variable by default
    # this script will call to this shell-within-a-shell which is captured in a variable (by default, global) called win_stats
    
    # We can then access this variable outside the function. 
    # This was the first technique learned for getting data out of a function.
}

# %%
# Calling the function using the city Etar.
get_number_wins Etar

# %%
# trying to access the win_stats global variable created inside the function with the echo command.
echo "The number of wins of the city of Etar was $win_stats"
# Out:
# The number of wins of the city of Etar was 15

# %%
############ Datacamp answer #################

# Create a function
function get_number_wins () {

  # Filter aggregate results by argument
  win_stats=$(cat soccer_scores.csv | cut -d "," -f2 | egrep -v 'Winner'| sort | uniq -c | egrep "$1")

}

# Call the function with specified argument
get_number_wins "Etar"

# Print out the global variable
echo "The aggregated stats are: $win_stats"

# %% [markdown]
# `bash script`
#
# The aggregated stats are:      15 Etar

# %% [markdown]
# This is a practical example to see one of the two methods for **accessing variables created inside of a function**; by **assigning to a global variable (in our case `win_stats`)** and accessing outside using `$` notation.
#
# Beware the use of global variables by default as unexpected things may occur if you don't keep track of them!

# %%
head ../data/soccer_scores.csv
# Out:
# ﻿Year,Winner,Winner Goals
# 1932,Arda,4
# 1933,Botev,1
# 1934,Cherno,5
# 1935,Dunav,2
# 1936,Cherno,4
# 1937,Dunav,4
# 1938,Beroe,5
# 1939,Botev,2
# 1940,Beroe,3

# %%
cat ../data/soccer_scores.csv | cut -d "," -f2 | head
# Out:
# Winner
# Arda
# Botev
# Cherno
# Dunav
# Cherno
# Dunav
# Beroe
# Botev
# Beroe

# %%
cat ../data/soccer_scores.csv | cut -d "," -f2 | egrep -v "Winner" | head
# Out:
# Arda
# Botev
# Cherno
# Dunav
# Cherno
# Dunav
# Beroe
# Botev
# Beroe
# Botev

# %%
cat ../data/soccer_scores.csv | cut -d "," -f2 | egrep -v "Winner" | sort | wc -l
# Out:
# 75

# %%
cat ../data/soccer_scores.csv | cut -d "," -f2 | egrep -v "Winner" | sort | uniq -c
# Out:
#      13 Arda
#       8 Beroe
#       9 Botev
#       8 Cherno
#      17 Dunav
#      15 Etar
#       4 Levski
#       1 Lokomotiv

# %%
cat ../data/soccer_scores.csv | cut -d "," -f2 | egrep -v "Winner" | sort | uniq -c | egrep "Etar"
# Out:
#      15 Etar

# %% [markdown]
# ### Summing an array - exercise
#
# A common programming task is obtaining the sum of an array of numbers. Let's create a function to assist with this common task.
#
# Create a Bash function that will take in an array of numbers and return its sum. We will use `bc` rather than `expr` to ensure we can handle decimals.
#
# Your company's security rules state that all variables in functions must be restricted local scope so you will need to keep this in mind.
#
# An array of numbers you can use for a test of your function would be the daily sales in your organization this week (in thousands):
#
# `14 12 23.5 16 19.34` which should sum to `84.84`
#
# **Instructions**
#
# * Create a function called `sum_array` and add a base variable (equal to 0) called `sum` with **local** scope. You will loop through the array and increment this variable.
# * Create a FOR loop through the ARGV array inside `sum_array` (hint: This is **not** `$1`! but another special array property) and increment `sum` with each element of the array.
# * Rather than assign to a global variable, `echo` back the result of your FOR loop summation.
# * Call your function using the test array provided and echo the result. You can capture the results of the function call using the shell-within-a-shell notation.

# %%
# Bash function that will take in an array of numbers and return its sum.

# creating the function
function sum_array () {
    # variable sum of local scope
    local sum=0
    
    # looping through elements of the ARGV array and adding them to the base variable sum
    for number in "$@"
    do
        sum=$(echo "scale=2; $sum + $number" | bc)
        #sum=$(echo "scale=2; sum+number" | bc)
        #((sum=sum+number))
        #sum=$((sum+number))
    done
    
    echo $sum
}

# %%
# Testing the function - version 1

# Calling the function using the test array provided and 
# capture the results of the function call using the shell-within-a-shell notation
test_sum_array=$(sum_array 14 12 23.5 16 19.34)

# %%
# echo the result
echo "The sum of the numbers in the array is $test_sum_array"
# Out:
# The sum of the numbers in the array is 84.84

# %%
# Testing the function - version 2

# making an array
test_array1=(14 12 23.5 16 19.34)
#echo ${test_array1[@]}

# Calling the function using the test array provided and 
# capture the results of the function call using the shell-within-a-shell notation
total_sum=$(sum_array "${test_array1[@]}")

# echo the result
echo "The total sum of the elements of the test array is $total_sum"
# Out:
# The total sum of the elements of the test array is 84.84

# %% [markdown]
# We have combined many different concepts in this exercise; arrays, functions, FOR loops, scope and variable arithmetic.
#
# Now We'll learn a super powerful function of Bash - scheduling your scripts with cron!

# %%
############ Datacamp answer #################

# Create a function with a local base variable
function sum_array () {
  local sum=0
  # Loop through, adding to base variable
  for number in "$@"
  do
    sum=$(echo "$sum + $number" | bc)
  done
  # Echo back the result
  echo $sum
  }
# Call function with array
test_array=(14 12 23.5 16 19.34)
total=$(sum_array "${test_array[@]}")
echo "The total sum of the test array is $total"

# %% [markdown]
# ## 3. Scheduling your scripts with Cron

# %% [markdown]
# Now you have mastered creating Bash scripts, let's learn how to program them to run on a schedule.
#
# You'll never need to lift a finger to execute code again!
#
# ![Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell1.png](attachment:Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell1.png)

# %% [markdown]
# ![Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell2.png](attachment:Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell2.png)

# %% [markdown]
# ### Crontab and cronjob structure
#
# ![Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell3.png](attachment:Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell3.png)

# %% [markdown]
# ... means run at 'every interval'.

# %% [markdown]
# ### Cronjob example
#
# In the first example (left):
#
# * The minutes star is 5 (meaning 5 minutes past the hour).
# * Which hour? Well, the hours star is 1 (meaning after 1am).
# * The last three are all stars, meaning 'every'.
# * So overall, we run myscript.sh every day (and month) at 1:05am.
#
# ![Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell4.png](attachment:Screenshot_2021-06-04%20Scheduling%20your%20scripts%20with%20Cron%20Shell4.png)
#
# In the second example (right):
#
# * The minutes star is 15 (meaning 15 minutes past the hour),
# * the hours star is 14 (meaning after 2pm).
# * The stars for day-of-month and month-of-year are 'every'. (every day of the month, every month of the year)
# * The last star is day 7 (on Sundays).
# * So overall we run myscript.sh at 2:15pm every Sunday.

# %% [markdown]
# ### Advanced cronjob structure
# For specific intervals, you can use a comma.
#
# For example, this cronjob would run at 15, 30 and 45 minutes past the hour, for every hour specified in the next star.
#
# Here it is every hour, every day etc.
#
# ![Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell5.png](attachment:Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell5.png)
#
# You can use a slash `/` for every X increment.
#
# In another example, this cronjob runs every 15 minutes. Again, for every hour, every day etc.

# %% [markdown]
# ### Your first cron job
#
# ![Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell6.png](attachment:Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell6.png)

# %% [markdown]
# ![Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell7.png](attachment:Screenshot_2021-06-05%20Scheduling%20your%20scripts%20with%20Cron%20Shell7.png)

# %%
crontab -e

# %%
crontab -l
# Out:
# # Edit this file to introduce tasks to be run by cron.
# #
# # Each task to run has to be defined through a single line
# # indicating with different fields when the task will be run
# # and what command to run for the task
# #
# # To define the time you can provide concrete values for
# # minute (m), hour (h), day of month (dom), month (mon),
# # and day of week (dow) or use '*' in these fields (for 'any').#
# # Notice that tasks will be started based on the cron's system
# # daemon's notion of time and timezones.
# #
# # Output of the crontab jobs (including errors) is sent through
# # email to the user the crontab file belongs to (unless redirected).
# #
# # For example, you can run a backup of all your user accounts
# # at 5 a.m every week with:
# # 0 5 * * 1 tar -zcf /var/backups/home.tgz /home/
# #
# # For more information see the manual pages of crontab(5) and cron(8)
# #
# # m h  dom mon dow   command
# 30 1 * * * extract_data.sh

# %% [markdown]
# Look at the last line:
#
# `30 1 * * * extract_data.sh`
#
# The job we added is running!

# %% [markdown]
# ### Analyzing a crontab schedule - Quiz
#
# ![Screenshot_2021-06-05_00-46-18.png](attachment:Screenshot_2021-06-05_00-46-18.png)

# %% [markdown]
# Correct!
#
# * The first star being 15 means 'run 15 minutes past the hour'.
# * The second star being a star means 'do this every hour'.
# * The last star is for the days of the week.
# * Hence 6 and 7 means to run on every 6th and 7th days of the week or all Saturdays and Sundays.

# %% [markdown]
# ### Creating cronjobs - exercise
#
# You are working as a data scientist managing an end-to-end machine learning environment in the cloud. You have created some great Bash scripts but it is becoming tedious to have to run these scripts every morning and afternoon. You recently learned about `cron` which you think can greatly assist here!
#
# An example file has been placed in your directory where you can create some crontab jobs.
#
# Remember that a crontab schedule has 5 stars relation to the time periods minute, hour, day-of-month, month-of-year, day-of-week. For this task, **assume Sunday is the 0th day** rather than the 7th day (as in some unix systems).
#
# Note that where all time periods are not specified in the instructions below, you can assume those time periods are 'every' (`*`).
#
# **Don't try to run the scripts or use crontab. Neither will work.**
#
# A useful tool for constructing crontabs is https://crontab.guru/.
#
# **Instructions**
#
# * Create a crontab schedule that runs `script1.sh` at 30 minutes past 2am every day.
# * Create a crontab schedule that runs `script2.sh` every 15, 30 and 45 minutes past every hour.
# * Create a crontab schedule that runs `script3.sh` at 11.30**pm** on Sunday evening, every week. For this task, **assume Sunday is the 0th day** rather than the 7th day (as in some unix systems).

# %%
# Create a schedule for 30 minutes past 2am every day
30 2 * * * bash script1.sh

# Create a schedule for every 15, 30 and 45 minutes past the hour
15,30,45 * * * * bash script2.sh

# Create a schedule for 11.30pm on Sunday evening, every week
30 23 * * 0 bash script3.sh

# %% [markdown]
# Great scheduling! There were some tricky ones in there but you got them all. This will save countless hours and ensure smooth execution of all your Bash scripts. What great efficiency!
#
# Links:
#
# * [crontab guru](https://crontab.guru/)
# * [Cron Helper](https://cron.help/)

# %% [markdown]
# ### Scheduling cronjobs with crontab - exercise
#
# As the resident data scientist, you have been asked to automate part of a data processing pipeline. You will use one of the `cronjob` schedules created in a previous exercise.
#
# You will use the built in `crontab` functionality of this workspace to schedule a data pipeline script, `extract_data.sh` to run at 30 minutes past 2am every day. Running early in the morning saves a great amount of cost by utilizing cheaper server power.
#
# You will end up in the `nano` text editor where you save a file with `ctrl` + `o` (press enter) and exit with `ctrl` + `x`. Useful Nano documentation is here.
#
# At any stage you can refresh your browser window and you will get a fresh workspace to try again if you accidentally make a mistake in the workspace.
#
# **Instructions**
#
# 1. Verify there are no existing cronjobs by listing them.

# %%
crontab -l

# %% [markdown]
# 2. Use the edit command for `crontab` (select `nano`) then schedule `extract_data.sh` to run with Bash at 2:30am every day.

# %%
crontab -e
# in nano or vim
30 2 * * * bash extract_data.sh

# %% [markdown]
# 3. Verify the `cronjob` has been scheduled in the `crontab` by listing all current scheduled `cronjobs`.

# %%
crontab -l

# %% [markdown]
# ![Screenshot_2021-06-05_01-08-17.png](attachment:Screenshot_2021-06-05_01-08-17.png)
#
# Nice work! You'll save lots of time and money with your newfound `crontab` skills.

# %% [markdown]
# ### Thanks and wrap up
#
# ![Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell1.png](attachment:Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell1.png)
#
# ![Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell2.png](attachment:Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell2.png)
#
# ![Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell3.png](attachment:Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell3.png)
#
# We used the shell-within-a-shell concept often.
#
# We could call a shell in-place and **capture the return value**. Just like in this simple example.
#
# ![Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell4.png](attachment:Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell4.png)
#
# ![Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell5.png](attachment:Screenshot_2021-06-05%20Thanks%20and%20wrap%20up%20Shell5.png)
